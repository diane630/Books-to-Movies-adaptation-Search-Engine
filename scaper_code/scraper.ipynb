# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
import time

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome("./chromedriver.exe",options=options)

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

#tidies extracted text 
def process_content(content):
    content = content.encode('ascii',errors='ignore').decode('utf-8')       #removes non-ascii characters
    content = re.sub('\s+',' ',content)       #repalces repeated whitespace characters with single space
    return content

''' More tidying
Sometimes the text extracted HTML webpage may contain javascript code and some style elements. 
This function removes script and style tags from HTML so that extracted text does not contain them.
'''
def remove_script(soup):
    for script in soup(["script", "style"]):
        script.decompose()
    return soup

# %%
#extracts all Faculty Profile page urls from the Directory Listing Page

def scrape_title_page(url):
    soup = get_js_soup(url,driver) 
    
    # story
    new_story = []
    plot = span = storyline =div_1 = div_2 = None
    # short
    span = soup.find('span', attrs={'class': re.compile('^GenresAndPlot__TextContainerBreakpoint.*')})
    if span:
        plot = span.get_text()
    # long
    div_1 = soup.find('div', attrs={'data-testid': 'storyline-plot-summary'})
    if div_1:
        div_2 = div_1.find('div', attrs={'class': 'ipc-html-content ipc-html-content--base'})
    if div_2:
        storyline = div_2.get_text()    
    if plot:
        new_story.append(plot)
    if storyline:
        new_story.append(storyline)
    new_story = " ".join(new_story)
    return new_story
    
def scrape_full_credit_page(url):
    fc_url = "/".join(url.split("/")[:-1]) + "/fullcredits"
    soup = get_js_soup(fc_url,driver) 
    
    # writer
    div = h4 = table = None
    div = soup.find('div', attrs={'id':"fullcredits_content"})
    if div:
        h4 = div.find('h4', attrs={'id':"writer"})
    if h4:
        table = h4.find_next_sibling("table").find('tbody')
    writers = set()
    if table:
        for td in table.find_all('td',class_='name'):
            doc = td.find('a')
            if doc:
                writers.add(doc.get_text().lstrip().rstrip())
    writers = ", ".join(writers)
    
    # characters
    table = None
    table = div.find('table', attrs={'class':"cast_list"})
    chars = set()
    if table:
        for td in table.find_all('td',class_='character'):
            doc = td.find('a')
            if doc:
                chars.add(doc.get_text().lstrip().rstrip())
    characters = ", ".join(chars)
    return writers, characters

def scrape_dir_page(dir_url,driver, i):
    base = 'https://www.imdb.com/'
    soup = get_js_soup(dir_url,driver) 
    batch = {'url':[], 'title':[], 'story':[], 'writers': [], 'characters':[]}
    for link_holder in soup.find_all('h3',class_='lister-item-header'): #get list of all <h2> of class 'entry-title fusion-post-title'
        doc = link_holder.find('a')
        
        link = doc['href'] #get url
        if not link:
            link = ""
        new_url = base + link
        
        title = doc.get_text() #get url  
        if not title:
            title = ""
        new_title = title
        
        new_story = scrape_title_page(new_url)
        new_writers, new_characters = scrape_full_credit_page(new_url)
        
        batch['url'].append(new_url)
        batch['title'].append(new_title)
        batch['story'].append(new_story)
        batch['writers'].append(new_writers)
        batch['characters'].append(new_characters)
#         break
    print ('-'*20,'Finish scraping {} movies'.format(str(50 * (i+1))),'-'*20)
    return batch

# %%
movie_urls = []
movie_titles = []
movie_stories = []
movie_writers = []
movie_characters = []

# %%
import time
# popularity descending order, scape first 200 pages (50 titles per page)
print ('-'*20,'Scraping directory page','-'*20)
# i should start from 1
last_i = 142
for i in range(last_i, 1000):
    dir_url = 'https://www.imdb.com/search/keyword/?mode=detail&page=' + str(i) + '&title_type=movie&ref_=kw_ref_key&sort=moviemeter,asc'
    try:
        batch = scrape_dir_page(dir_url,driver, i)
        movie_urls.extend(batch['url'])
        movie_titles.extend(batch['title'])
        movie_stories.extend(batch['story'])
        movie_writers.extend(batch['writers'])
        movie_characters.extend(batch['characters'])
        last_i += 1
    except:
        time.sleep(1)
        batch = scrape_dir_page(dir_url,driver, i)
        movie_urls.extend(batch['url'])
        movie_titles.extend(batch['title'])
        movie_stories.extend(batch['story'])
        movie_writers.extend(batch['writers'])
        movie_characters.extend(batch['characters'])
        last_i += 1
# Out:
# -------------------- Scraping directory page --------------------
# -------------------- Finish scraping 7150 movies --------------------
# -------------------- Finish scraping 7200 movies --------------------
# -------------------- Finish scraping 7250 movies --------------------
# -------------------- Finish scraping 7300 movies --------------------
# -------------------- Finish scraping 7350 movies --------------------
# -------------------- Finish scraping 7400 movies --------------------
# -------------------- Finish scraping 7450 movies --------------------
# -------------------- Finish scraping 7500 movies --------------------
# -------------------- Finish scraping 7550 movies --------------------
# -------------------- Finish scraping 7600 movies --------------------
# -------------------- Finish scraping 7650 movies --------------------
# -------------------- Finish scraping 7700 movies --------------------
# -------------------- Finish scraping 7750 movies --------------------
# -------------------- Finish scraping 7800 movies --------------------
# -------------------- Finish scraping 7850 movies --------------------
# -------------------- Finish scraping 7900 movies --------------------
# -------------------- Finish scraping 7950 movies --------------------
# -------------------- Finish scraping 8000 movies --------------------
# -------------------- Finish scraping 8050 movies --------------------
# -------------------- Finish scraping 8100 movies --------------------
# -------------------- Finish scraping 8150 movies --------------------
# -------------------- Finish scraping 8200 movies --------------------
# -------------------- Finish scraping 8250 movies --------------------
# -------------------- Finish scraping 8300 movies --------------------
# -------------------- Finish scraping 8350 movies --------------------
# -------------------- Finish scraping 8400 movies --------------------
# -------------------- Finish scraping 8450 movies --------------------
# -------------------- Finish scraping 8500 movies --------------------
# -------------------- Finish scraping 8550 movies --------------------
# -------------------- Finish scraping 8600 movies --------------------
# -------------------- Finish scraping 8650 movies --------------------
# -------------------- Finish scraping 8700 movies --------------------
# -------------------- Finish scraping 8750 movies --------------------
# -------------------- Finish scraping 8800 movies --------------------
# -------------------- Finish scraping 8850 movies --------------------
# -------------------- Finish scraping 8900 movies --------------------
# -------------------- Finish scraping 8950 movies --------------------
# -------------------- Finish scraping 9000 movies --------------------
# -------------------- Finish scraping 9050 movies --------------------
# -------------------- Finish scraping 9100 movies --------------------
# -------------------- Finish scraping 9150 movies --------------------
# -------------------- Finish scraping 9200 movies --------------------
# -------------------- Finish scraping 9250 movies --------------------
# -------------------- Finish scraping 9300 movies --------------------
# -------------------- Finish scraping 9350 movies --------------------
# -------------------- Finish scraping 9400 movies --------------------
# -------------------- Finish scraping 9450 movies --------------------
# -------------------- Finish scraping 9500 movies --------------------
# -------------------- Finish scraping 9550 movies --------------------
# -------------------- Finish scraping 9600 movies --------------------
# -------------------- Finish scraping 9650 movies --------------------
# -------------------- Finish scraping 9700 movies --------------------
# -------------------- Finish scraping 9750 movies --------------------
# -------------------- Finish scraping 9800 movies --------------------
# -------------------- Finish scraping 9850 movies --------------------
# -------------------- Finish scraping 9900 movies --------------------
# -------------------- Finish scraping 9950 movies --------------------
# -------------------- Finish scraping 10000 movies --------------------
# -------------------- Finish scraping 10050 movies --------------------
# -------------------- Finish scraping 10100 movies --------------------
# -------------------- Finish scraping 10150 movies --------------------
# -------------------- Finish scraping 10200 movies --------------------
# -------------------- Finish scraping 10250 movies --------------------
# -------------------- Finish scraping 10300 movies --------------------
# -------------------- Finish scraping 10350 movies --------------------
# -------------------- Finish scraping 10400 movies --------------------
# -------------------- Finish scraping 10450 movies --------------------
# -------------------- Finish scraping 10500 movies --------------------
# -------------------- Finish scraping 10550 movies --------------------
# -------------------- Finish scraping 10600 movies --------------------
# -------------------- Finish scraping 10650 movies --------------------
# -------------------- Finish scraping 10700 movies --------------------
# -------------------- Finish scraping 10750 movies --------------------
# -------------------- Finish scraping 10800 movies --------------------
# -------------------- Finish scraping 10850 movies --------------------
# -------------------- Finish scraping 10900 movies --------------------
# -------------------- Finish scraping 10950 movies --------------------
# -------------------- Finish scraping 11000 movies --------------------
# -------------------- Finish scraping 11050 movies --------------------
# -------------------- Finish scraping 11100 movies --------------------
# -------------------- Finish scraping 11150 movies --------------------
# -------------------- Finish scraping 11200 movies --------------------
# -------------------- Finish scraping 11250 movies --------------------
# -------------------- Finish scraping 11300 movies --------------------
# -------------------- Finish scraping 11350 movies --------------------
# -------------------- Finish scraping 11400 movies --------------------
# -------------------- Finish scraping 11450 movies --------------------
# -------------------- Finish scraping 11500 movies --------------------
# -------------------- Finish scraping 11550 movies --------------------
# -------------------- Finish scraping 11600 movies --------------------
# -------------------- Finish scraping 11650 movies --------------------
# -------------------- Finish scraping 11700 movies --------------------
# -------------------- Finish scraping 11750 movies --------------------
# -------------------- Finish scraping 11800 movies --------------------
# -------------------- Finish scraping 11850 movies --------------------
# -------------------- Finish scraping 11900 movies --------------------
# -------------------- Finish scraping 11950 movies --------------------
# -------------------- Finish scraping 12000 movies --------------------
# -------------------- Finish scraping 12050 movies --------------------
# -------------------- Finish scraping 12100 movies --------------------
# -------------------- Finish scraping 12150 movies --------------------
# -------------------- Finish scraping 12200 movies --------------------
# -------------------- Finish scraping 12250 movies --------------------
# -------------------- Finish scraping 12300 movies --------------------
# -------------------- Finish scraping 12350 movies --------------------
# -------------------- Finish scraping 12400 movies --------------------
# -------------------- Finish scraping 12450 movies --------------------
# -------------------- Finish scraping 12500 movies --------------------
# -------------------- Finish scraping 12550 movies --------------------
# -------------------- Finish scraping 12600 movies --------------------
# -------------------- Finish scraping 12650 movies --------------------
# -------------------- Finish scraping 12700 movies --------------------
# -------------------- Finish scraping 12750 movies --------------------
# -------------------- Finish scraping 12800 movies --------------------
# -------------------- Finish scraping 12850 movies --------------------
# -------------------- Finish scraping 12900 movies --------------------
# -------------------- Finish scraping 12950 movies --------------------
# -------------------- Finish scraping 13000 movies --------------------
# -------------------- Finish scraping 13050 movies --------------------
# -------------------- Finish scraping 13100 movies --------------------
# -------------------- Finish scraping 13150 movies --------------------
# -------------------- Finish scraping 13200 movies --------------------
# -------------------- Finish scraping 13250 movies --------------------
# -------------------- Finish scraping 13300 movies --------------------
# -------------------- Finish scraping 13350 movies --------------------
# -------------------- Finish scraping 13400 movies --------------------
# -------------------- Finish scraping 13450 movies --------------------
# -------------------- Finish scraping 13500 movies --------------------
# -------------------- Finish scraping 13550 movies --------------------
# -------------------- Finish scraping 13600 movies --------------------
# -------------------- Finish scraping 13650 movies --------------------
# -------------------- Finish scraping 13700 movies --------------------
# -------------------- Finish scraping 13750 movies --------------------
# -------------------- Finish scraping 13800 movies --------------------
# -------------------- Finish scraping 13850 movies --------------------
# -------------------- Finish scraping 13900 movies --------------------
# -------------------- Finish scraping 13950 movies --------------------
# -------------------- Finish scraping 14000 movies --------------------
# -------------------- Finish scraping 14050 movies --------------------
# -------------------- Finish scraping 14100 movies --------------------
# -------------------- Finish scraping 14150 movies --------------------
# -------------------- Finish scraping 14200 movies --------------------
# -------------------- Finish scraping 14250 movies --------------------
# -------------------- Finish scraping 14300 movies --------------------
# -------------------- Finish scraping 14350 movies --------------------
# -------------------- Finish scraping 14400 movies --------------------
# -------------------- Finish scraping 14450 movies --------------------
# -------------------- Finish scraping 14500 movies --------------------
# -------------------- Finish scraping 14550 movies --------------------
# -------------------- Finish scraping 14600 movies --------------------
# -------------------- Finish scraping 14650 movies --------------------
# -------------------- Finish scraping 14700 movies --------------------
# -------------------- Finish scraping 14750 movies --------------------
# -------------------- Finish scraping 14800 movies --------------------
# -------------------- Finish scraping 14850 movies --------------------
# -------------------- Finish scraping 14900 movies --------------------
# -------------------- Finish scraping 14950 movies --------------------
# -------------------- Finish scraping 15000 movies --------------------
# -------------------- Finish scraping 15050 movies --------------------
# -------------------- Finish scraping 15100 movies --------------------
# -------------------- Finish scraping 15150 movies --------------------
# -------------------- Finish scraping 15200 movies --------------------
# -------------------- Finish scraping 15250 movies --------------------
# -------------------- Finish scraping 15300 movies --------------------
# -------------------- Finish scraping 15350 movies --------------------
# -------------------- Finish scraping 15400 movies --------------------
# -------------------- Finish scraping 15450 movies --------------------
# -------------------- Finish scraping 15500 movies --------------------
# -------------------- Finish scraping 15550 movies --------------------
# -------------------- Finish scraping 15600 movies --------------------
# -------------------- Finish scraping 15650 movies --------------------
# -------------------- Finish scraping 15700 movies --------------------
# -------------------- Finish scraping 15750 movies --------------------
# -------------------- Finish scraping 15800 movies --------------------
# -------------------- Finish scraping 15850 movies --------------------
# -------------------- Finish scraping 15900 movies --------------------
# -------------------- Finish scraping 15950 movies --------------------
# -------------------- Finish scraping 16000 movies --------------------
# -------------------- Finish scraping 16050 movies --------------------
# -------------------- Finish scraping 16100 movies --------------------
# -------------------- Finish scraping 16150 movies --------------------
# -------------------- Finish scraping 16200 movies --------------------
# -------------------- Finish scraping 16250 movies --------------------
# -------------------- Finish scraping 16300 movies --------------------
# -------------------- Finish scraping 16350 movies --------------------
# -------------------- Finish scraping 16400 movies --------------------
# -------------------- Finish scraping 16450 movies --------------------
# -------------------- Finish scraping 16500 movies --------------------
# -------------------- Finish scraping 16550 movies --------------------
# -------------------- Finish scraping 16600 movies --------------------
# -------------------- Finish scraping 16650 movies --------------------
# -------------------- Finish scraping 16700 movies --------------------
# -------------------- Finish scraping 16750 movies --------------------
# -------------------- Finish scraping 16800 movies --------------------
# -------------------- Finish scraping 16850 movies --------------------
# -------------------- Finish scraping 16900 movies --------------------
# -------------------- Finish scraping 16950 movies --------------------
# -------------------- Finish scraping 17000 movies --------------------
# -------------------- Finish scraping 17050 movies --------------------
# -------------------- Finish scraping 17100 movies --------------------
# -------------------- Finish scraping 17150 movies --------------------
# -------------------- Finish scraping 17200 movies --------------------
# -------------------- Finish scraping 17250 movies --------------------
# -------------------- Finish scraping 17300 movies --------------------
# -------------------- Finish scraping 17350 movies --------------------
# -------------------- Finish scraping 17400 movies --------------------
# -------------------- Finish scraping 17450 movies --------------------
# -------------------- Finish scraping 17500 movies --------------------
# -------------------- Finish scraping 17550 movies --------------------
# -------------------- Finish scraping 17600 movies --------------------
# -------------------- Finish scraping 17650 movies --------------------
# -------------------- Finish scraping 17700 movies --------------------
# -------------------- Finish scraping 17750 movies --------------------
# -------------------- Finish scraping 17800 movies --------------------
# -------------------- Finish scraping 17850 movies --------------------
# -------------------- Finish scraping 17900 movies --------------------
# -------------------- Finish scraping 17950 movies --------------------
# -------------------- Finish scraping 18000 movies --------------------
# -------------------- Finish scraping 18050 movies --------------------
# -------------------- Finish scraping 18100 movies --------------------
# -------------------- Finish scraping 18150 movies --------------------
# -------------------- Finish scraping 18200 movies --------------------
# -------------------- Finish scraping 18250 movies --------------------
# -------------------- Finish scraping 18300 movies --------------------
# -------------------- Finish scraping 18350 movies --------------------
# -------------------- Finish scraping 18400 movies --------------------
# -------------------- Finish scraping 18450 movies --------------------
# -------------------- Finish scraping 18500 movies --------------------
# -------------------- Finish scraping 18550 movies --------------------
# -------------------- Finish scraping 18600 movies --------------------
# -------------------- Finish scraping 18650 movies --------------------
# -------------------- Finish scraping 18700 movies --------------------
# -------------------- Finish scraping 18750 movies --------------------
# -------------------- Finish scraping 18800 movies --------------------
# -------------------- Finish scraping 18850 movies --------------------
# -------------------- Finish scraping 18900 movies --------------------
# -------------------- Finish scraping 18950 movies --------------------
# -------------------- Finish scraping 19000 movies --------------------
# -------------------- Finish scraping 19050 movies --------------------
# -------------------- Finish scraping 19100 movies --------------------
# -------------------- Finish scraping 19150 movies --------------------
# -------------------- Finish scraping 19200 movies --------------------
# -------------------- Finish scraping 19250 movies --------------------
# -------------------- Finish scraping 19300 movies --------------------
# -------------------- Finish scraping 19350 movies --------------------
# -------------------- Finish scraping 19400 movies --------------------
# -------------------- Finish scraping 19450 movies --------------------
# -------------------- Finish scraping 19500 movies --------------------
# -------------------- Finish scraping 19550 movies --------------------
# -------------------- Finish scraping 19600 movies --------------------
# -------------------- Finish scraping 19650 movies --------------------
# -------------------- Finish scraping 19700 movies --------------------
# -------------------- Finish scraping 19750 movies --------------------
# -------------------- Finish scraping 19800 movies --------------------
# -------------------- Finish scraping 19850 movies --------------------
# -------------------- Finish scraping 19900 movies --------------------
# -------------------- Finish scraping 19950 movies --------------------
# -------------------- Finish scraping 20000 movies --------------------
# -------------------- Finish scraping 20050 movies --------------------
# -------------------- Finish scraping 20100 movies --------------------
# -------------------- Finish scraping 20150 movies --------------------
# -------------------- Finish scraping 20200 movies --------------------
# -------------------- Finish scraping 20250 movies --------------------
# -------------------- Finish scraping 20300 movies --------------------
# -------------------- Finish scraping 20350 movies --------------------
# -------------------- Finish scraping 20400 movies --------------------
# -------------------- Finish scraping 20450 movies --------------------
# -------------------- Finish scraping 20500 movies --------------------
# -------------------- Finish scraping 20550 movies --------------------
# -------------------- Finish scraping 20600 movies --------------------
# -------------------- Finish scraping 20650 movies --------------------
# -------------------- Finish scraping 20700 movies --------------------
# -------------------- Finish scraping 20750 movies --------------------
# -------------------- Finish scraping 20800 movies --------------------
# -------------------- Finish scraping 20850 movies --------------------
# -------------------- Finish scraping 20900 movies --------------------
# -------------------- Finish scraping 20950 movies --------------------
# -------------------- Finish scraping 21000 movies --------------------
# -------------------- Finish scraping 21050 movies --------------------
# -------------------- Finish scraping 21100 movies --------------------
# -------------------- Finish scraping 21150 movies --------------------
# -------------------- Finish scraping 21200 movies --------------------
# -------------------- Finish scraping 21250 movies --------------------
# -------------------- Finish scraping 21300 movies --------------------
# -------------------- Finish scraping 21350 movies --------------------
# -------------------- Finish scraping 21400 movies --------------------
# -------------------- Finish scraping 21450 movies --------------------
# -------------------- Finish scraping 21500 movies --------------------
# -------------------- Finish scraping 21550 movies --------------------
# -------------------- Finish scraping 21600 movies --------------------
# -------------------- Finish scraping 21650 movies --------------------
# -------------------- Finish scraping 21700 movies --------------------
# -------------------- Finish scraping 21750 movies --------------------
# -------------------- Finish scraping 21800 movies --------------------
# -------------------- Finish scraping 21850 movies --------------------
# -------------------- Finish scraping 21900 movies --------------------
# -------------------- Finish scraping 21950 movies --------------------
# -------------------- Finish scraping 22000 movies --------------------
# -------------------- Finish scraping 22050 movies --------------------
# -------------------- Finish scraping 22100 movies --------------------
# -------------------- Finish scraping 22150 movies --------------------
# -------------------- Finish scraping 22200 movies --------------------
# -------------------- Finish scraping 22250 movies --------------------
# -------------------- Finish scraping 22300 movies --------------------
# -------------------- Finish scraping 22350 movies --------------------
# -------------------- Finish scraping 22400 movies --------------------
# -------------------- Finish scraping 22450 movies --------------------
# -------------------- Finish scraping 22500 movies --------------------
# -------------------- Finish scraping 22550 movies --------------------
# -------------------- Finish scraping 22600 movies --------------------
# -------------------- Finish scraping 22650 movies --------------------
# -------------------- Finish scraping 22700 movies --------------------
# -------------------- Finish scraping 22750 movies --------------------
# -------------------- Finish scraping 22800 movies --------------------
# -------------------- Finish scraping 22850 movies --------------------
# -------------------- Finish scraping 22900 movies --------------------
# -------------------- Finish scraping 22950 movies --------------------
# -------------------- Finish scraping 23000 movies --------------------
# -------------------- Finish scraping 23050 movies --------------------
# -------------------- Finish scraping 23100 movies --------------------
# -------------------- Finish scraping 23150 movies --------------------
# -------------------- Finish scraping 23200 movies --------------------
# -------------------- Finish scraping 23250 movies --------------------
# -------------------- Finish scraping 23300 movies --------------------
# -------------------- Finish scraping 23350 movies --------------------
# -------------------- Finish scraping 23400 movies --------------------
# -------------------- Finish scraping 23450 movies --------------------
# -------------------- Finish scraping 23500 movies --------------------
# -------------------- Finish scraping 23550 movies --------------------
# -------------------- Finish scraping 23600 movies --------------------
# -------------------- Finish scraping 23650 movies --------------------
# -------------------- Finish scraping 23700 movies --------------------
# -------------------- Finish scraping 23750 movies --------------------
# -------------------- Finish scraping 23800 movies --------------------
# -------------------- Finish scraping 23850 movies --------------------
# -------------------- Finish scraping 23900 movies --------------------
# -------------------- Finish scraping 23950 movies --------------------
# -------------------- Finish scraping 24000 movies --------------------
# -------------------- Finish scraping 24050 movies --------------------
# -------------------- Finish scraping 24100 movies --------------------
# -------------------- Finish scraping 24150 movies --------------------
# -------------------- Finish scraping 24200 movies --------------------
# -------------------- Finish scraping 24250 movies --------------------
# -------------------- Finish scraping 24300 movies --------------------
# -------------------- Finish scraping 24350 movies --------------------
# -------------------- Finish scraping 24400 movies --------------------
# -------------------- Finish scraping 24450 movies --------------------
# -------------------- Finish scraping 24500 movies --------------------
# -------------------- Finish scraping 24550 movies --------------------
# -------------------- Finish scraping 24600 movies --------------------
# -------------------- Finish scraping 24650 movies --------------------
# -------------------- Finish scraping 24700 movies --------------------
# -------------------- Finish scraping 24750 movies --------------------
# -------------------- Finish scraping 24800 movies --------------------
# -------------------- Finish scraping 24850 movies --------------------
# -------------------- Finish scraping 24900 movies --------------------
# -------------------- Finish scraping 24950 movies --------------------
# -------------------- Finish scraping 25000 movies --------------------
# -------------------- Finish scraping 25050 movies --------------------
# -------------------- Finish scraping 25100 movies --------------------
# -------------------- Finish scraping 25150 movies --------------------
# -------------------- Finish scraping 25200 movies --------------------
# -------------------- Finish scraping 25250 movies --------------------
# -------------------- Finish scraping 25300 movies --------------------
# -------------------- Finish scraping 25350 movies --------------------
# -------------------- Finish scraping 25400 movies --------------------
# -------------------- Finish scraping 25450 movies --------------------
# -------------------- Finish scraping 25500 movies --------------------
# -------------------- Finish scraping 25550 movies --------------------
# -------------------- Finish scraping 25600 movies --------------------
# -------------------- Finish scraping 25650 movies --------------------
# -------------------- Finish scraping 25700 movies --------------------
# -------------------- Finish scraping 25750 movies --------------------
# -------------------- Finish scraping 25800 movies --------------------
# -------------------- Finish scraping 25850 movies --------------------
# -------------------- Finish scraping 25900 movies --------------------
# -------------------- Finish scraping 25950 movies --------------------
# -------------------- Finish scraping 26000 movies --------------------
# -------------------- Finish scraping 26050 movies --------------------
# -------------------- Finish scraping 26100 movies --------------------
# -------------------- Finish scraping 26150 movies --------------------
# -------------------- Finish scraping 26200 movies --------------------
# -------------------- Finish scraping 26250 movies --------------------
# -------------------- Finish scraping 26300 movies --------------------
# -------------------- Finish scraping 26350 movies --------------------
# -------------------- Finish scraping 26400 movies --------------------
# -------------------- Finish scraping 26450 movies --------------------
# -------------------- Finish scraping 26500 movies --------------------
# -------------------- Finish scraping 26550 movies --------------------
# -------------------- Finish scraping 26600 movies --------------------
# -------------------- Finish scraping 26650 movies --------------------
# -------------------- Finish scraping 26700 movies --------------------
# -------------------- Finish scraping 26750 movies --------------------
# -------------------- Finish scraping 26800 movies --------------------
# -------------------- Finish scraping 26850 movies --------------------
# -------------------- Finish scraping 26900 movies --------------------
# -------------------- Finish scraping 26950 movies --------------------
# -------------------- Finish scraping 27000 movies --------------------
# -------------------- Finish scraping 27050 movies --------------------
# -------------------- Finish scraping 27100 movies --------------------
# -------------------- Finish scraping 27150 movies --------------------
# -------------------- Finish scraping 27200 movies --------------------
# -------------------- Finish scraping 27250 movies --------------------
# -------------------- Finish scraping 27300 movies --------------------
# -------------------- Finish scraping 27350 movies --------------------
# -------------------- Finish scraping 27400 movies --------------------
# -------------------- Finish scraping 27450 movies --------------------
# -------------------- Finish scraping 27500 movies --------------------
# -------------------- Finish scraping 27550 movies --------------------
# -------------------- Finish scraping 27600 movies --------------------
# -------------------- Finish scraping 27650 movies --------------------
# -------------------- Finish scraping 27700 movies --------------------
# -------------------- Finish scraping 27750 movies --------------------
# -------------------- Finish scraping 27800 movies --------------------
# -------------------- Finish scraping 27850 movies --------------------
# -------------------- Finish scraping 27900 movies --------------------
# -------------------- Finish scraping 27950 movies --------------------
# -------------------- Finish scraping 28000 movies --------------------
# -------------------- Finish scraping 28050 movies --------------------
# -------------------- Finish scraping 28100 movies --------------------
# -------------------- Finish scraping 28150 movies --------------------
# -------------------- Finish scraping 28200 movies --------------------
# -------------------- Finish scraping 28250 movies --------------------
# -------------------- Finish scraping 28300 movies --------------------
# -------------------- Finish scraping 28350 movies --------------------
# -------------------- Finish scraping 28400 movies --------------------
# -------------------- Finish scraping 28450 movies --------------------
# -------------------- Finish scraping 28500 movies --------------------
# -------------------- Finish scraping 28550 movies --------------------
# -------------------- Finish scraping 28600 movies --------------------
# -------------------- Finish scraping 28650 movies --------------------
# -------------------- Finish scraping 28700 movies --------------------
# -------------------- Finish scraping 28750 movies --------------------
# -------------------- Finish scraping 28800 movies --------------------
# -------------------- Finish scraping 28850 movies --------------------
# -------------------- Finish scraping 28900 movies --------------------
# -------------------- Finish scraping 28950 movies --------------------
# -------------------- Finish scraping 29000 movies --------------------
# -------------------- Finish scraping 29050 movies --------------------
# -------------------- Finish scraping 29100 movies --------------------
# -------------------- Finish scraping 29150 movies --------------------
# -------------------- Finish scraping 29200 movies --------------------
# -------------------- Finish scraping 29250 movies --------------------
# -------------------- Finish scraping 29300 movies --------------------
# -------------------- Finish scraping 29350 movies --------------------
# -------------------- Finish scraping 29400 movies --------------------
# -------------------- Finish scraping 29450 movies --------------------
# -------------------- Finish scraping 29500 movies --------------------
# -------------------- Finish scraping 29550 movies --------------------
# -------------------- Finish scraping 29600 movies --------------------
# -------------------- Finish scraping 29650 movies --------------------
# -------------------- Finish scraping 29700 movies --------------------
# -------------------- Finish scraping 29750 movies --------------------
# -------------------- Finish scraping 29800 movies --------------------
# -------------------- Finish scraping 29850 movies --------------------
# -------------------- Finish scraping 29900 movies --------------------
# -------------------- Finish scraping 29950 movies --------------------
# -------------------- Finish scraping 30000 movies --------------------
# -------------------- Finish scraping 30050 movies --------------------
# -------------------- Finish scraping 30100 movies --------------------
# -------------------- Finish scraping 30150 movies --------------------
# -------------------- Finish scraping 30200 movies --------------------
# -------------------- Finish scraping 30250 movies --------------------
# -------------------- Finish scraping 30300 movies --------------------
# -------------------- Finish scraping 30350 movies --------------------
# -------------------- Finish scraping 30400 movies --------------------
# -------------------- Finish scraping 30450 movies --------------------
# -------------------- Finish scraping 30500 movies --------------------
# -------------------- Finish scraping 30550 movies --------------------
# -------------------- Finish scraping 30600 movies --------------------
# -------------------- Finish scraping 30650 movies --------------------
# -------------------- Finish scraping 30700 movies --------------------
# -------------------- Finish scraping 30750 movies --------------------
# -------------------- Finish scraping 30800 movies --------------------
# -------------------- Finish scraping 30850 movies --------------------
# -------------------- Finish scraping 30900 movies --------------------
# -------------------- Finish scraping 30950 movies --------------------
# -------------------- Finish scraping 31000 movies --------------------
# -------------------- Finish scraping 31050 movies --------------------
# -------------------- Finish scraping 31100 movies --------------------
# -------------------- Finish scraping 31150 movies --------------------
# -------------------- Finish scraping 31200 movies --------------------
# -------------------- Finish scraping 31250 movies --------------------
# -------------------- Finish scraping 31300 movies --------------------
# -------------------- Finish scraping 31350 movies --------------------
# -------------------- Finish scraping 31400 movies --------------------
# -------------------- Finish scraping 31450 movies --------------------
# -------------------- Finish scraping 31500 movies --------------------
# -------------------- Finish scraping 31550 movies --------------------
# -------------------- Finish scraping 31600 movies --------------------
# -------------------- Finish scraping 31650 movies --------------------
# -------------------- Finish scraping 31700 movies --------------------
# -------------------- Finish scraping 31750 movies --------------------
# -------------------- Finish scraping 31800 movies --------------------
# -------------------- Finish scraping 31850 movies --------------------
# -------------------- Finish scraping 31900 movies --------------------
# -------------------- Finish scraping 31950 movies --------------------
# -------------------- Finish scraping 32000 movies --------------------
# -------------------- Finish scraping 32050 movies --------------------
# -------------------- Finish scraping 32100 movies --------------------
# -------------------- Finish scraping 32150 movies --------------------
# -------------------- Finish scraping 32200 movies --------------------
# -------------------- Finish scraping 32250 movies --------------------
# -------------------- Finish scraping 32300 movies --------------------
# -------------------- Finish scraping 32350 movies --------------------
# -------------------- Finish scraping 32400 movies --------------------
# -------------------- Finish scraping 32450 movies --------------------
# -------------------- Finish scraping 32500 movies --------------------
# -------------------- Finish scraping 32550 movies --------------------
# -------------------- Finish scraping 32600 movies --------------------
# -------------------- Finish scraping 32650 movies --------------------
# -------------------- Finish scraping 32700 movies --------------------
# -------------------- Finish scraping 32750 movies --------------------
# -------------------- Finish scraping 32800 movies --------------------
# -------------------- Finish scraping 32850 movies --------------------
# -------------------- Finish scraping 32900 movies --------------------
# -------------------- Finish scraping 32950 movies --------------------
# -------------------- Finish scraping 33000 movies --------------------
# -------------------- Finish scraping 33050 movies --------------------
# -------------------- Finish scraping 33100 movies --------------------
# -------------------- Finish scraping 33150 movies --------------------
# -------------------- Finish scraping 33200 movies --------------------
# -------------------- Finish scraping 33250 movies --------------------
# -------------------- Finish scraping 33300 movies --------------------
# -------------------- Finish scraping 33350 movies --------------------
# -------------------- Finish scraping 33400 movies --------------------
# -------------------- Finish scraping 33450 movies --------------------
# -------------------- Finish scraping 33500 movies --------------------
# -------------------- Finish scraping 33550 movies --------------------
# -------------------- Finish scraping 33600 movies --------------------
# -------------------- Finish scraping 33650 movies --------------------
# -------------------- Finish scraping 33700 movies --------------------
# -------------------- Finish scraping 33750 movies --------------------
# -------------------- Finish scraping 33800 movies --------------------
# -------------------- Finish scraping 33850 movies --------------------
# -------------------- Finish scraping 33900 movies --------------------
# -------------------- Finish scraping 33950 movies --------------------
# -------------------- Finish scraping 34000 movies --------------------
# -------------------- Finish scraping 34050 movies --------------------
# -------------------- Finish scraping 34100 movies --------------------
# -------------------- Finish scraping 34150 movies --------------------
# -------------------- Finish scraping 34200 movies --------------------
# -------------------- Finish scraping 34250 movies --------------------
# -------------------- Finish scraping 34300 movies --------------------
# -------------------- Finish scraping 34350 movies --------------------
# -------------------- Finish scraping 34400 movies --------------------
# -------------------- Finish scraping 34450 movies --------------------
# -------------------- Finish scraping 34500 movies --------------------
# -------------------- Finish scraping 34550 movies --------------------
# -------------------- Finish scraping 34600 movies --------------------
# -------------------- Finish scraping 34650 movies --------------------
# -------------------- Finish scraping 34700 movies --------------------
# -------------------- Finish scraping 34750 movies --------------------
# -------------------- Finish scraping 34800 movies --------------------
# -------------------- Finish scraping 34850 movies --------------------
# -------------------- Finish scraping 34900 movies --------------------
# -------------------- Finish scraping 34950 movies --------------------
# -------------------- Finish scraping 35000 movies --------------------
# -------------------- Finish scraping 35050 movies --------------------
# -------------------- Finish scraping 35100 movies --------------------
# -------------------- Finish scraping 35150 movies --------------------
# -------------------- Finish scraping 35200 movies --------------------
# -------------------- Finish scraping 35250 movies --------------------
# -------------------- Finish scraping 35300 movies --------------------
# -------------------- Finish scraping 35350 movies --------------------
# -------------------- Finish scraping 35400 movies --------------------
# -------------------- Finish scraping 35450 movies --------------------
# -------------------- Finish scraping 35500 movies --------------------
# -------------------- Finish scraping 35550 movies --------------------
# -------------------- Finish scraping 35600 movies --------------------
# -------------------- Finish scraping 35650 movies --------------------
# -------------------- Finish scraping 35700 movies --------------------
# -------------------- Finish scraping 35750 movies --------------------
# -------------------- Finish scraping 35800 movies --------------------
# -------------------- Finish scraping 35850 movies --------------------
# -------------------- Finish scraping 35900 movies --------------------
# -------------------- Finish scraping 35950 movies --------------------
# -------------------- Finish scraping 36000 movies --------------------
# -------------------- Finish scraping 36050 movies --------------------
# -------------------- Finish scraping 36100 movies --------------------
# -------------------- Finish scraping 36150 movies --------------------
# -------------------- Finish scraping 36200 movies --------------------
# -------------------- Finish scraping 36250 movies --------------------
# -------------------- Finish scraping 36300 movies --------------------
# -------------------- Finish scraping 36350 movies --------------------
# -------------------- Finish scraping 36400 movies --------------------
# -------------------- Finish scraping 36450 movies --------------------
# -------------------- Finish scraping 36500 movies --------------------
# -------------------- Finish scraping 36550 movies --------------------
# -------------------- Finish scraping 36600 movies --------------------
# -------------------- Finish scraping 36650 movies --------------------
# -------------------- Finish scraping 36700 movies --------------------
# -------------------- Finish scraping 36750 movies --------------------
# -------------------- Finish scraping 36800 movies --------------------
# -------------------- Finish scraping 36850 movies --------------------
# -------------------- Finish scraping 36900 movies --------------------
# -------------------- Finish scraping 36950 movies --------------------
# -------------------- Finish scraping 37000 movies --------------------
# -------------------- Finish scraping 37050 movies --------------------
# -------------------- Finish scraping 37100 movies --------------------
# -------------------- Finish scraping 37150 movies --------------------
# -------------------- Finish scraping 37200 movies --------------------
# -------------------- Finish scraping 37250 movies --------------------
# -------------------- Finish scraping 37300 movies --------------------
# -------------------- Finish scraping 37350 movies --------------------
# -------------------- Finish scraping 37400 movies --------------------
# -------------------- Finish scraping 37450 movies --------------------
# -------------------- Finish scraping 37500 movies --------------------
# -------------------- Finish scraping 37550 movies --------------------
# -------------------- Finish scraping 37600 movies --------------------
# -------------------- Finish scraping 37650 movies --------------------
# -------------------- Finish scraping 37700 movies --------------------
# -------------------- Finish scraping 37750 movies --------------------
# -------------------- Finish scraping 37800 movies --------------------
# -------------------- Finish scraping 37850 movies --------------------
# -------------------- Finish scraping 37900 movies --------------------
# -------------------- Finish scraping 37950 movies --------------------
# -------------------- Finish scraping 38000 movies --------------------
# -------------------- Finish scraping 38050 movies --------------------
# -------------------- Finish scraping 38100 movies --------------------
# -------------------- Finish scraping 38150 movies --------------------
# -------------------- Finish scraping 38200 movies --------------------
# -------------------- Finish scraping 38250 movies --------------------
# -------------------- Finish scraping 38300 movies --------------------
# -------------------- Finish scraping 38350 movies --------------------
# -------------------- Finish scraping 38400 movies --------------------
# -------------------- Finish scraping 38450 movies --------------------
# -------------------- Finish scraping 38500 movies --------------------
# -------------------- Finish scraping 38550 movies --------------------
# -------------------- Finish scraping 38600 movies --------------------
# -------------------- Finish scraping 38650 movies --------------------
# -------------------- Finish scraping 38700 movies --------------------
# -------------------- Finish scraping 38750 movies --------------------
# -------------------- Finish scraping 38800 movies --------------------
# -------------------- Finish scraping 38850 movies --------------------
# -------------------- Finish scraping 38900 movies --------------------
# -------------------- Finish scraping 38950 movies --------------------
# -------------------- Finish scraping 39000 movies --------------------
# -------------------- Finish scraping 39050 movies --------------------
# -------------------- Finish scraping 39100 movies --------------------
# -------------------- Finish scraping 39150 movies --------------------
# -------------------- Finish scraping 39200 movies --------------------
# -------------------- Finish scraping 39250 movies --------------------
# -------------------- Finish scraping 39300 movies --------------------
# -------------------- Finish scraping 39350 movies --------------------
# -------------------- Finish scraping 39400 movies --------------------
# -------------------- Finish scraping 39450 movies --------------------
# -------------------- Finish scraping 39500 movies --------------------
# -------------------- Finish scraping 39550 movies --------------------
# -------------------- Finish scraping 39600 movies --------------------
# -------------------- Finish scraping 39650 movies --------------------
# -------------------- Finish scraping 39700 movies --------------------
# -------------------- Finish scraping 39750 movies --------------------
# -------------------- Finish scraping 39800 movies --------------------
# -------------------- Finish scraping 39850 movies --------------------
# -------------------- Finish scraping 39900 movies --------------------
# -------------------- Finish scraping 39950 movies --------------------
# -------------------- Finish scraping 40000 movies --------------------
# -------------------- Finish scraping 40050 movies --------------------
# -------------------- Finish scraping 40100 movies --------------------
# -------------------- Finish scraping 40150 movies --------------------
# -------------------- Finish scraping 40200 movies --------------------
# -------------------- Finish scraping 40250 movies --------------------
# -------------------- Finish scraping 40300 movies --------------------
# -------------------- Finish scraping 40350 movies --------------------
# -------------------- Finish scraping 40400 movies --------------------
# -------------------- Finish scraping 40450 movies --------------------
# -------------------- Finish scraping 40500 movies --------------------
# -------------------- Finish scraping 40550 movies --------------------
# -------------------- Finish scraping 40600 movies --------------------
# -------------------- Finish scraping 40650 movies --------------------
# -------------------- Finish scraping 40700 movies --------------------
# -------------------- Finish scraping 40750 movies --------------------
# -------------------- Finish scraping 40800 movies --------------------
# -------------------- Finish scraping 40850 movies --------------------
# -------------------- Finish scraping 40900 movies --------------------
# -------------------- Finish scraping 40950 movies --------------------
# -------------------- Finish scraping 41000 movies --------------------
# -------------------- Finish scraping 41050 movies --------------------
# -------------------- Finish scraping 41100 movies --------------------
# -------------------- Finish scraping 41150 movies --------------------
# -------------------- Finish scraping 41200 movies --------------------
# -------------------- Finish scraping 41250 movies --------------------
# -------------------- Finish scraping 41300 movies --------------------
# -------------------- Finish scraping 41350 movies --------------------
# -------------------- Finish scraping 41400 movies --------------------
# -------------------- Finish scraping 41450 movies --------------------
# -------------------- Finish scraping 41500 movies --------------------
# -------------------- Finish scraping 41550 movies --------------------
# -------------------- Finish scraping 41600 movies --------------------
# -------------------- Finish scraping 41650 movies --------------------
# -------------------- Finish scraping 41700 movies --------------------
# -------------------- Finish scraping 41750 movies --------------------
# -------------------- Finish scraping 41800 movies --------------------
# -------------------- Finish scraping 41850 movies --------------------
# -------------------- Finish scraping 41900 movies --------------------
# -------------------- Finish scraping 41950 movies --------------------
# -------------------- Finish scraping 42000 movies --------------------
# -------------------- Finish scraping 42050 movies --------------------
# -------------------- Finish scraping 42100 movies --------------------
# -------------------- Finish scraping 42150 movies --------------------
# -------------------- Finish scraping 42200 movies --------------------
# -------------------- Finish scraping 42250 movies --------------------
# -------------------- Finish scraping 42300 movies --------------------
# -------------------- Finish scraping 42350 movies --------------------
# -------------------- Finish scraping 42400 movies --------------------
# -------------------- Finish scraping 42450 movies --------------------
# -------------------- Finish scraping 42500 movies --------------------
# -------------------- Finish scraping 42550 movies --------------------
# -------------------- Finish scraping 42600 movies --------------------
# -------------------- Finish scraping 42650 movies --------------------
# -------------------- Finish scraping 42700 movies --------------------
# -------------------- Finish scraping 42750 movies --------------------
# -------------------- Finish scraping 42800 movies --------------------
# -------------------- Finish scraping 42850 movies --------------------
# -------------------- Finish scraping 42900 movies --------------------
# -------------------- Finish scraping 42950 movies --------------------
# -------------------- Finish scraping 43000 movies --------------------
# -------------------- Finish scraping 43050 movies --------------------
# -------------------- Finish scraping 43100 movies --------------------
# -------------------- Finish scraping 43150 movies --------------------
# -------------------- Finish scraping 43200 movies --------------------
# -------------------- Finish scraping 43250 movies --------------------
# -------------------- Finish scraping 43300 movies --------------------
# -------------------- Finish scraping 43350 movies --------------------
# -------------------- Finish scraping 43400 movies --------------------
# -------------------- Finish scraping 43450 movies --------------------
# -------------------- Finish scraping 43500 movies --------------------
# -------------------- Finish scraping 43550 movies --------------------
# -------------------- Finish scraping 43600 movies --------------------
# -------------------- Finish scraping 43650 movies --------------------
# -------------------- Finish scraping 43700 movies --------------------
# -------------------- Finish scraping 43750 movies --------------------
# -------------------- Finish scraping 43800 movies --------------------
# -------------------- Finish scraping 43850 movies --------------------
# -------------------- Finish scraping 43900 movies --------------------
# -------------------- Finish scraping 43950 movies --------------------
# -------------------- Finish scraping 44000 movies --------------------
# -------------------- Finish scraping 44050 movies --------------------
# -------------------- Finish scraping 44100 movies --------------------
# -------------------- Finish scraping 44150 movies --------------------
# -------------------- Finish scraping 44200 movies --------------------
# -------------------- Finish scraping 44250 movies --------------------
# -------------------- Finish scraping 44300 movies --------------------
# -------------------- Finish scraping 44350 movies --------------------
# -------------------- Finish scraping 44400 movies --------------------
# -------------------- Finish scraping 44450 movies --------------------
# -------------------- Finish scraping 44500 movies --------------------
# -------------------- Finish scraping 44550 movies --------------------
# -------------------- Finish scraping 44600 movies --------------------
# -------------------- Finish scraping 44650 movies --------------------
# -------------------- Finish scraping 44700 movies --------------------
# -------------------- Finish scraping 44750 movies --------------------
# -------------------- Finish scraping 44800 movies --------------------
# -------------------- Finish scraping 44850 movies --------------------
# -------------------- Finish scraping 44900 movies --------------------
# -------------------- Finish scraping 44950 movies --------------------
# -------------------- Finish scraping 45000 movies --------------------
# -------------------- Finish scraping 45050 movies --------------------
# -------------------- Finish scraping 45100 movies --------------------
# -------------------- Finish scraping 45150 movies --------------------
# -------------------- Finish scraping 45200 movies --------------------
# -------------------- Finish scraping 45250 movies --------------------
# -------------------- Finish scraping 45300 movies --------------------
# -------------------- Finish scraping 45350 movies --------------------
# -------------------- Finish scraping 45400 movies --------------------
# -------------------- Finish scraping 45450 movies --------------------
# -------------------- Finish scraping 45500 movies --------------------
# -------------------- Finish scraping 45550 movies --------------------
# -------------------- Finish scraping 45600 movies --------------------
# -------------------- Finish scraping 45650 movies --------------------
# -------------------- Finish scraping 45700 movies --------------------
# -------------------- Finish scraping 45750 movies --------------------
# -------------------- Finish scraping 45800 movies --------------------
# -------------------- Finish scraping 45850 movies --------------------
# -------------------- Finish scraping 45900 movies --------------------
# -------------------- Finish scraping 45950 movies --------------------
# -------------------- Finish scraping 46000 movies --------------------
# -------------------- Finish scraping 46050 movies --------------------
# -------------------- Finish scraping 46100 movies --------------------
# -------------------- Finish scraping 46150 movies --------------------
# -------------------- Finish scraping 46200 movies --------------------
# -------------------- Finish scraping 46250 movies --------------------
# -------------------- Finish scraping 46300 movies --------------------
# -------------------- Finish scraping 46350 movies --------------------
# -------------------- Finish scraping 46400 movies --------------------
# -------------------- Finish scraping 46450 movies --------------------
# -------------------- Finish scraping 46500 movies --------------------
# -------------------- Finish scraping 46550 movies --------------------
# -------------------- Finish scraping 46600 movies --------------------
# -------------------- Finish scraping 46650 movies --------------------
# -------------------- Finish scraping 46700 movies --------------------
# -------------------- Finish scraping 46750 movies --------------------
# -------------------- Finish scraping 46800 movies --------------------
# -------------------- Finish scraping 46850 movies --------------------
# -------------------- Finish scraping 46900 movies --------------------
# -------------------- Finish scraping 46950 movies --------------------
# -------------------- Finish scraping 47000 movies --------------------
# -------------------- Finish scraping 47050 movies --------------------
# -------------------- Finish scraping 47100 movies --------------------
# -------------------- Finish scraping 47150 movies --------------------
# -------------------- Finish scraping 47200 movies --------------------
# -------------------- Finish scraping 47250 movies --------------------
# -------------------- Finish scraping 47300 movies --------------------
# -------------------- Finish scraping 47350 movies --------------------
# -------------------- Finish scraping 47400 movies --------------------
# -------------------- Finish scraping 47450 movies --------------------
# -------------------- Finish scraping 47500 movies --------------------
# -------------------- Finish scraping 47550 movies --------------------
# -------------------- Finish scraping 47600 movies --------------------
# -------------------- Finish scraping 47650 movies --------------------
# -------------------- Finish scraping 47700 movies --------------------
# -------------------- Finish scraping 47750 movies --------------------
# -------------------- Finish scraping 47800 movies --------------------
# -------------------- Finish scraping 47850 movies --------------------
# -------------------- Finish scraping 47900 movies --------------------
# -------------------- Finish scraping 47950 movies --------------------
# -------------------- Finish scraping 48000 movies --------------------
# -------------------- Finish scraping 48050 movies --------------------
# -------------------- Finish scraping 48100 movies --------------------
# -------------------- Finish scraping 48150 movies --------------------
# -------------------- Finish scraping 48200 movies --------------------
# -------------------- Finish scraping 48250 movies --------------------
# -------------------- Finish scraping 48300 movies --------------------
# -------------------- Finish scraping 48350 movies --------------------
# -------------------- Finish scraping 48400 movies --------------------
# -------------------- Finish scraping 48450 movies --------------------
# -------------------- Finish scraping 48500 movies --------------------
# -------------------- Finish scraping 48550 movies --------------------
# -------------------- Finish scraping 48600 movies --------------------
# -------------------- Finish scraping 48650 movies --------------------
# -------------------- Finish scraping 48700 movies --------------------
# -------------------- Finish scraping 48750 movies --------------------
# -------------------- Finish scraping 48800 movies --------------------
# -------------------- Finish scraping 48850 movies --------------------
# -------------------- Finish scraping 48900 movies --------------------
# -------------------- Finish scraping 48950 movies --------------------
# -------------------- Finish scraping 49000 movies --------------------
# -------------------- Finish scraping 49050 movies --------------------
# -------------------- Finish scraping 49100 movies --------------------
# -------------------- Finish scraping 49150 movies --------------------
# -------------------- Finish scraping 49200 movies --------------------
# -------------------- Finish scraping 49250 movies --------------------
# -------------------- Finish scraping 49300 movies --------------------
# -------------------- Finish scraping 49350 movies --------------------
# -------------------- Finish scraping 49400 movies --------------------
# -------------------- Finish scraping 49450 movies --------------------
# -------------------- Finish scraping 49500 movies --------------------
# -------------------- Finish scraping 49550 movies --------------------
# -------------------- Finish scraping 49600 movies --------------------
# -------------------- Finish scraping 49650 movies --------------------
# -------------------- Finish scraping 49700 movies --------------------
# -------------------- Finish scraping 49750 movies --------------------
# -------------------- Finish scraping 49800 movies --------------------
# -------------------- Finish scraping 49850 movies --------------------
# -------------------- Finish scraping 49900 movies --------------------
# -------------------- Finish scraping 49950 movies --------------------
# -------------------- Finish scraping 50000 movies --------------------

# %%
movie_urls[-10:]
print(len(movie_urls))
# Out:
# 9999

# %%
movie_titles[-10:]
print(len(movie_titles))
# Out:
# 9999

# %%
movie_writers[-10:]
print(len(movie_writers))
# Out:
# 9999

# %%
movie_stories[-10:]
print(len(movie_stories))
# Out:
# 9999

# %%
movie_characters[:-10]
print(len(movie_characters))
# Out:
# 9999

# %%
last_i
# Out:
# 1000

# %%
def write_lst(lst,file_):
    with open(file_,'w') as f:
        for l in lst:
            f.write(process_content(l))
            f.write('\n')

# %%
movie_urls_file = '../IMDB_Goodreads_data/movie_urls.txt'
movie_writers_file = '../IMDB_Goodreads_data/movie_writers.txt'
movie_stories_file = '../IMDB_Goodreads_data/movie_stories.txt'
movie_titles_file = '../IMDB_Goodreads_data/movie_titles.txt'
movie_characters_file = '../IMDB_Goodreads_data/movie_characters.txt'

write_lst(movie_urls,movie_urls_file)
write_lst(movie_writers,movie_writers_file)
write_lst(movie_stories,movie_stories_file)
write_lst(movie_titles,movie_titles_file)
write_lst(movie_characters,movie_characters_file)
